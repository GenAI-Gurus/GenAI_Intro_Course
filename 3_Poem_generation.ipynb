# %%
# !pip install openai==0.27.0
# !pip install python-dotenv

# %%
import os
import openai

# %%
openai.api_key = 'your key'
os.environ['OPENAI_API_KEY'] = openai.api_key

# %%
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())
openai.api_key = os.environ['OPENAI_API_KEY']

# %%
Poem_generation = openai.Completion.create(
  model="text-davinci-003",
  prompt="""
#write a poem on peace
  """,
  max_tokens=100,
  temperature=.66
)
print(str(Poem_generation["choices"][0]["text"]))
# Out:
# Peace be not just a dream,
# But a reality that can be seen.
# May we all find peace within,
# No matter our color or skin.
#
# Let us embrace our differences,
# And work together to find peace.
# Let us live in harmony,
# Where we can all be free.
#
# Let us share love and understanding,
# And work together to be standing.
# Let us strive for a world of peace
